# %%
from SimpleEnv import SimpleEnv


env = SimpleEnv(render_mode="human")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import SimpleEnv
# ----> 4 env = SimpleEnv(render_mode="human")
#
# TypeError: 'module' object is not callable. Did you mean: 'SimpleEnv.SimpleEnv(...)'?
